# %% [markdown]
# # Boluwatife Yomi-Adeyemi

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# Our project tried to find out if there is a possibility of life outside our solar system.

# %%
import pandas as pd
planet_spreadsheet=pd.read_csv('../data/raw/DataOriginal.csv')
planet_spreadsheet.head()
# Out:
#    No. Planet Name Planet Host  Num Stars  Num Planets Discovery Method  \
# 0    1    11 Com b      11 Com          2            1  Radial Velocity
# 1    2    11 UMi b      11 UMi          1            1  Radial Velocity
# 2    3    14 And b      14 And          1            1  Radial Velocity
# 3    4    14 Her b      14 Her          1            2  Radial Velocity
# 4    5  16 Cyg B b    16 Cyg B          3            1  Radial Velocity
#
#    Discovery Year                      Discovery Facility  \
# 0            2007                        Xinglong Station
# 1            2009  Thueringer Landessternwarte Tautenburg
# 2            2008       Okayama Astrophysical Observatory
# 3            2002                  W. M. Keck Observatory
# 4            1996                  Multiple Observatories
#
#    Orbital Period Days  Orbit Semi-Major Axis  ...  Equilibrium Temperature  \
# 0            326.03000                   1.29  ...                      NaN
# ...

# %%
import pandas as pd
file = '../data/raw/DataOriginal.csv'
planet = pd.read_csv(file)
planet.describe()
# Out:
#               No.    Num Stars  Num Planets  Discovery Year  \
# count  4575.00000  4575.000000  4575.000000     4575.000000
# mean   2288.00000     1.109945     1.787760     2014.862951
# std    1320.83307     0.351677     1.166591        3.960923
# min       1.00000     1.000000     1.000000     1989.000000
# 25%    1144.50000     1.000000     1.000000     2014.000000
# 50%    2288.00000     1.000000     1.000000     2016.000000
# 75%    3431.50000     1.000000     2.000000     2016.000000
# max    4575.00000     4.000000     8.000000     2021.000000
#
#        Orbital Period Days  Orbit Semi-Major Axis          Mass  Eccentricity  \
# count         4.413000e+03            2763.000000   2006.000000   1707.000000
# mean          9.489932e+04              10.940380    725.123682      0.154910
# std           6.053595e+06             182.398887   1338.016965      0.183289
# min           9.070629e-02               0.004400      0.020000      0.000000
# ...

# %% [markdown]
# #Discovery Method used to calculate the data

# %%
import pandas as pd
df = pd.read_csv("../data/raw/DataOriginal.csv")
import matplotlib.pyplot as plot

bar = df.groupby(['Discovery Year','Discovery Facility']).size().unstack()
bar.plot.bar(stacked=True, figsize=(9,5))
plot.show()

# %% [markdown]
# #What planets have the highest orbital period days
# To determine the habitability of a planet in any solar system, we have to first be sure of the orbital properties, mass, possibility of liquid water and so on.

# %%
import pandas as pd 
df = pd.read_csv("../data/raw/DataOriginal.csv")


Orbital_days = ['Planet Name','Num Stars','Num Planets','Orbital Period Days'] 
df9 = df[Orbital_days]


df11=df9.sort_values(['Orbital Period Days'], ascending = False)
df11.dropna(subset=['Orbital Period Days'])
df16=df11.head(10)

df16.plot.bar(x="Planet Name", y="Orbital Period Days",rot=70, title="Bar Chart displaying the Orbital Period Days each planet has")
# Out:
# <AxesSubplot:title={'center':'Bar Chart displaying the Orbital Period Days each planet has'}, xlabel='Planet Name'>

# %% [markdown]
# #What planets have the most stars?
# This analysis will help us determine the planets with the most stars

# %%
import pandas as pd 
df = pd.read_csv("../data/raw/DataOriginal.csv")


stars = ['Planet Name','Num Stars'] 
df12 = df[stars]


df13=df12.sort_values(['Num Stars'], ascending = False)
df17=df13.head(10)

df17.plot.bar(x="Planet Name", y="Num Stars",rot=70, title="Bar Chart displaying the Number of Stars each planet has")
# Out:
# <AxesSubplot:title={'center':'Bar Chart displaying the Number of Stars each planet has'}, xlabel='Planet Name'>

# %% [markdown]
# #What methods were used to discover the planets?
# This analysis will help us discover the most popular method of discovering planets

# %%
import pandas as pd
df = pd.read_csv("../data/raw/DataOriginal.csv")


discover1 = ['Discovery Method','Planet Name']
df19 = df[discover1]

df19.head()

df20 = df19.groupby('Discovery Method').count()
df21=df20.rename(columns={'Planet Name':'Num Times'})
df21.reset_index(inplace=True)
df21

df21.plot.bar(x="Discovery Method", y="Num Times",rot=70, title="Bar Chart displaying the Number of Times a method was used to discover a planet")
# Out:
# <AxesSubplot:title={'center':'Bar Chart displaying the Number of Times a method was used to discover a planet'}, xlabel='Discovery Method'>

# %% [markdown]
# #Who discovered the planet and when?
# This analysis will help us determine what facility discovered a planet and the year they discovered it.

# %%
import pandas as pd
df = pd.read_csv("../data/raw/DataOriginal.csv")


discover = ['Discovery Facility','Discovery Year','Planet Name']
df14 = df[discover]
df15=df14.sort_values(['Discovery Year'], ascending=False)
df15
# Out:
#               Discovery Facility  Discovery Year            Planet Name
# 4146                        OGLE            2021  OGLE-2019-BLG-0954L b
# 135                           K2            2021       EPIC 206024342 d
# 1610                      Kepler            2021             KOI-3503 b
# 138                           K2            2021       EPIC 206042996 c
# 924       Multiple Observatories            2021              HD 4760 b
# ...                          ...             ...                    ...
# 26    Haute-Provence Observatory            1995               51 Peg b
# 4162         Arecibo Observatory            1994         PSR B1257+12 b
# 4163         Arecibo Observatory            1992         PSR B1257+12 c
# 4164         Arecibo Observatory            1992         PSR B1257+12 d
# 491        Oak Ridge Observatory            1989            HD 114762 b
#
# [4575 rows x 3 columns]

# %% [markdown]
# #Analysis Pipeline

# %%
import pandas as pd 
df = pd.read_csv("../data/raw/DataOriginal.csv")
df = df.sort_values('Discovery Year',ascending=True)
df.head()
# Out:
#        No.     Planet Name   Planet Host  Num Stars  Num Planets  \
# 491    492     HD 114762 b     HD 114762          2            1
# 4163  4164  PSR B1257+12 c  PSR B1257+12          1            3
# 4164  4165  PSR B1257+12 d  PSR B1257+12          1            3
# 4162  4163  PSR B1257+12 b  PSR B1257+12          1            3
# 26      27        51 Peg b        51 Peg          1            1
#
#      Discovery Method  Discovery Year          Discovery Facility  \
# 491   Radial Velocity            1989       Oak Ridge Observatory
# 4163    Pulsar Timing            1992         Arecibo Observatory
# 4164    Pulsar Timing            1992         Arecibo Observatory
# 4162    Pulsar Timing            1994         Arecibo Observatory
# 26    Radial Velocity            1995  Haute-Provence Observatory
#
#       Orbital Period Days  Orbit Semi-Major Axis  ...  \
# 491             83.915100                 0.3600  ...
# 4163            66.541900                 0.3600  ...
# ...

# %%
import pandas as pd
df41 = pd.read_csv("../data/raw/DataOriginal.csv")
df41.drop(['Equilibrium Temperature', 'Insolation Flux','Eccentricity','Spectral Type','Gaia Magnitude'], axis=1)
# Out:
#        No. Planet Name Planet Host  Num Stars  Num Planets Discovery Method  \
# 0        1    11 Com b      11 Com          2            1  Radial Velocity
# 1        2    11 UMi b      11 UMi          1            1  Radial Velocity
# 2        3    14 And b      14 And          1            1  Radial Velocity
# 3        4    14 Her b      14 Her          1            2  Radial Velocity
# 4        5  16 Cyg B b    16 Cyg B          3            1  Radial Velocity
# ...    ...         ...         ...        ...          ...              ...
# 4570  4571   tau Gem b     tau Gem          1            1  Radial Velocity
# 4571  4572   ups And b     ups And          2            3  Radial Velocity
# 4572  4573   ups And c     ups And          2            3  Radial Velocity
# 4573  4574   ups And d     ups And          2            3  Radial Velocity
# 4574  4575    xi Aql b      xi Aql          1            1  Radial Velocity
#
# ...

# %% [markdown]
# #Method Chaining
# In this stage, we attempt to clean data, make other methods to amend the data in the table better and also remove some columns or rows that are not needed so we can see only the specifics.

# %%
df4 = pd.read_csv("../data/raw/DataOriginal.csv")
df4
# Out:
#        No. Planet Name Planet Host  Num Stars  Num Planets Discovery Method  \
# 0        1    11 Com b      11 Com          2            1  Radial Velocity
# 1        2    11 UMi b      11 UMi          1            1  Radial Velocity
# 2        3    14 And b      14 And          1            1  Radial Velocity
# 3        4    14 Her b      14 Her          1            2  Radial Velocity
# 4        5  16 Cyg B b    16 Cyg B          3            1  Radial Velocity
# ...    ...         ...         ...        ...          ...              ...
# 4570  4571   tau Gem b     tau Gem          1            1  Radial Velocity
# 4571  4572   ups And b     ups And          2            3  Radial Velocity
# 4572  4573   ups And c     ups And          2            3  Radial Velocity
# 4573  4574   ups And d     ups And          2            3  Radial Velocity
# 4574  4575    xi Aql b      xi Aql          1            1  Radial Velocity
#
# ...

# %%
def change_and_drop(url_or_path_to_csv_file):

        df5 = (
              pd.read_csv(url_or_path_to_csv_file)    
              .drop(['Insolation Flux', 'Equilibrium Temperature', 'Eccentricity','Spectral Type','Gaia Magnitude'], axis=1)  
            .dropna(axis=0)
            .sort_values(['Discovery Year'], ascending=False)
            )
        
        return df5

# %%
change_and_drop("../data/raw/DataOriginal.csv")
# Out:
#        No.  Planet Name Planet Host  Num Stars  Num Planets Discovery Method  \
# 478    479  HD 110113 b   HD 110113          1            2          Transit
# 1099  1100  HIP 75092 b   HIP 75092          1            1  Radial Velocity
# 735    736  HD 207897 b   HD 207897          1            1          Transit
# 227    228   GJ 414 A c    GJ 414 A          2            2  Radial Velocity
# 226    227   GJ 414 A b    GJ 414 A          2            2  Radial Velocity
# ...    ...          ...         ...        ...          ...              ...
# 22      23     47 UMa b      47 UMa          1            3  Radial Velocity
# 4        5   16 Cyg B b    16 Cyg B          3            1  Radial Velocity
# 4565  4566    tau Boo b     tau Boo          2            1  Radial Velocity
# 26      27     51 Peg b      51 Peg          1            1  Radial Velocity
# 491    492  HD 114762 b   HD 114762          2            1  Radial Velocity
#
# ...

# %%
import project_functions3 
df44 = project_functions3.load_and_process("../data/raw/DataOriginal.csv")
df44
# Out:
#      Planet Name Host Star of Planet  Num Stars  Num Planets Discovery Method  \
# 0       11 Com b              11 Com          2            1  Radial Velocity
# 2       14 And b              14 And          1            1  Radial Velocity
# 5       17 Sco b              17 Sco          1            1  Radial Velocity
# 6       18 Del b              18 Del          2            1  Radial Velocity
# 8       24 Boo b              24 Boo          1            1  Radial Velocity
# ...          ...                 ...        ...          ...              ...
# 4558   ome Ser b             ome Ser          2            1  Radial Velocity
# 4561    pi Men c            HD 39091          1            2          Transit
# 4563   rho CrB b             rho CrB          1            2  Radial Velocity
# 4564   rho CrB c             rho CrB          1            2  Radial Velocity
# 4570   tau Gem b             tau Gem          1            1  Radial Velocity
#
# ...
