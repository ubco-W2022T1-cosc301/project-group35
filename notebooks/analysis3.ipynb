# %% [markdown]
# # Kevin Ruan

# %% [markdown]
# ## Research question/interests
#
# Briefly describe your research question or interests here.
#
# We are interested in furthering our knowledge and our understanding of potentially life sustaining exo-planets and associating human techologies that are used to achieve this.

# %%
import pandas as pd
spreadsheet=pd.read_csv('../data/raw/DataOriginal.csv')
spreadsheet.head()
# Out:
#    No. Planet Name Planet Host  Num Stars  Num Planets Discovery Method  \
# 0    1    11 Com b      11 Com          2            1  Radial Velocity
# 1    2    11 UMi b      11 UMi          1            1  Radial Velocity
# 2    3    14 And b      14 And          1            1  Radial Velocity
# 3    4    14 Her b      14 Her          1            2  Radial Velocity
# 4    5  16 Cyg B b    16 Cyg B          3            1  Radial Velocity
#
#    Discovery Year                      Discovery Facility  \
# 0            2007                        Xinglong Station
# 1            2009  Thueringer Landessternwarte Tautenburg
# 2            2008       Okayama Astrophysical Observatory
# 3            2002                  W. M. Keck Observatory
# 4            1996                  Multiple Observatories
#
#    Orbital Period Days  Orbit Semi-Major Axis  ...  Equilibrium Temperature  \
# 0            326.03000                   1.29  ...                      NaN
# ...

# %% [markdown]
# ## How far are these exoplanets from us?

# %% [markdown]
# Currently, the feasibility of in-depth research and information gathering is higher the closer these exo-planets are to us. This data is measured in light years and illustrates the exo-planets within 10 light years. The exo-planets in the table, while not being the most likely to sustain life, are the closest too us therefore have the highest possiblity of scientific research and analysis.

# %%
import pandas as pd 
df = pd.read_csv("../data/raw/DataOriginal.csv")


DistanceTest = ['Planet Name','Num Planets','Mass','Distance']
DF = df[DistanceTest]

Count=DF.sort_values(['Distance'], ascending = True)
Count=pd.DataFrame(Count)
Count=Count[0:11]
Count
# Out:
#         Planet Name  Num Planets      Mass  Distance
# 4171  Proxima Cen b            1    1.2700   1.30119
# 4545      eps Eri b            1  247.9074   3.20260
# 269        GJ 887 b            2    4.2000   3.29000
# 270        GJ 887 c            2    7.6000   3.29000
# 4185     Ross 128 b            1    1.4000   3.37454
# 179       GJ 15 A b            2    3.0300   3.56228
# 180       GJ 15 A c            2   36.0000   3.56228
# 4569      tau Cet h            4    1.8300   3.60304
# 4568      tau Cet g            4    1.7500   3.60304
# 4567      tau Cet f            4    3.9300   3.60304
# 4566      tau Cet e            4    3.9300   3.60304

# %% [markdown]
# Proxima Cen b is shown to be the planet that is closest to us at a distance of around 1.3 light years. The closer they are to us offers a hgiher chance of exploration.

# %% [markdown]
# ## Exoplanets Discovered by year

# %% [markdown]
# This is the count of exoplanets discovered per year and the exponential increase can be seen clearly here that demonstrates the technological advances we have produced.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("../data/raw/DataOriginal.csv")
ax = sns.countplot(data = df, x = 'Discovery Year', palette = 'rocket')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right", fontsize=6)
ax.set_xlabel("Discovery Year", fontsize=10)
ax.set_ylabel("Count of Exoplanets discovered", fontsize=10)
ax.set_title("Exoplanets Discovered per Year", fontsize=10)
plt.savefig('kevin1')

# %% [markdown]
# ## The Discovery of Exo-planets

# %% [markdown]
# The discovery of exo-planets increased exponentially through the years with advances in science and technology. The number of found exo-planets increased along with the distance of exo-planets. New and improved technology enabled us to see further away than ever before.

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("../data/raw/DataOriginal.csv")
ax = sns.displot(data=df, x="Discovery Year", y="Distance")
plt.savefig('kevin2')

# %% [markdown]
# ## Similarities in orbital period
# This is an example of how some planets do have many similarities to Earth, however, it does not help in determining if they can sustain life but they it does goes to show the effort in the search for Earth-like planets.

# %%
import pandas as pd
df = pd.read_csv("../data/raw/DataOriginal.csv")
DistanceTest = ['Planet Name','Num Planets','Discovery Year', 'Mass','Distance','Orbital Period Days']
DF = df[DistanceTest]
Count=DF.sort_values(['Orbital Period Days'], ascending = True)
Count=pd.DataFrame(Count)
#Count=Count[3910:3930]
Count=Count.dropna(subset=["Orbital Period Days"])
Count=Count[4405:4415]
Count
# Out:
#            Planet Name  Num Planets  Discovery Year        Mass  Distance  \
# 825         HD 26161 b            1            2021  4290.68349   40.9128
# 1118         HR 8799 d            4            2008  3000.00000   41.2441
# 960         HD 66428 c            2            2021  8581.36699   53.2817
# 1117         HR 8799 c            4            2008  3000.00000   41.2441
# 1116         HR 8799 b            4            2008  2000.00000   41.2441
# 4155          Oph 11 b            1            2006  4449.62000       NaN
# 72    CFHTWIR-Oph 98 b            1            2021  2479.06157       NaN
# 75        COCONUTS-2 b            1            2021  2002.31896   10.8864
#
#       Orbital Period Days
# 825               32000.0
# 1118              37000.0
# 960               39000.0
# 1117              69000.0
# 1116             170000.0
# 4155            7300000.0
# 72              8040000.0
# 75            402000000.0

# %% [markdown]
# ## Orbital Periods Days

# %% [markdown]
# This is the graph of the orbital period in days of exoplanets after the exclusion of several outliers, this shows how the trend as mass increases the orbital period tends to decrease and shows how Earth-sized planets tend to be closer to the sun or its star

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv("../data/raw/DataOriginal.csv")
df.dropna(subset=["Orbital Period Days"])
ax = sns.scatterplot(data=df[-(df['Orbital Period Days'] > 69000)], x = 'Mass', y = 'Orbital Period Days')
ax.set_title("Mass in relation to Orbital Period")
plt.savefig('kevin3')

# %% [markdown]
# # Analysis Pipeline

# %% [markdown]
# 1. Load data is done
# 2. Clean data
# -The No., Insolation Flux, and Equilibrium Temperature columns do not show any relevant data for a majority of the planets so they can be cleaned to produce more refined data.

# %%
import pandas as pd 
df = pd.read_csv("../data/raw/DataOriginal.csv")
df = df.sort_values('Discovery Year',ascending=True)
df.head()
# Out:
#        No.     Planet Name   Planet Host  Num Stars  Num Planets  \
# 491    492     HD 114762 b     HD 114762          2            1
# 4163  4164  PSR B1257+12 c  PSR B1257+12          1            3
# 4164  4165  PSR B1257+12 d  PSR B1257+12          1            3
# 4162  4163  PSR B1257+12 b  PSR B1257+12          1            3
# 26      27        51 Peg b        51 Peg          1            1
#
#      Discovery Method  Discovery Year          Discovery Facility  \
# 491   Radial Velocity            1989       Oak Ridge Observatory
# 4163    Pulsar Timing            1992         Arecibo Observatory
# 4164    Pulsar Timing            1992         Arecibo Observatory
# 4162    Pulsar Timing            1994         Arecibo Observatory
# 26    Radial Velocity            1995  Haute-Provence Observatory
#
#       Orbital Period Days  Orbit Semi-Major Axis  ...  \
# 491             83.915100                 0.3600  ...
# 4163            66.541900                 0.3600  ...
# ...

# %%
import pandas as pd 
data_r = pd.read_csv("../data/raw/DataOriginal.csv")
data_c = data_r.copy().drop(['No.','Insolation Flux', 'Equilibrium Temperature'], axis=1).dropna(axis=0)
data_c.reset_index()
data_c.head()
# Out:
#   Planet Name Planet Host  Num Stars  Num Planets Discovery Method  \
# 0    11 Com b      11 Com          2            1  Radial Velocity
# 2    14 And b      14 And          1            1  Radial Velocity
# 5    17 Sco b      17 Sco          1            1  Radial Velocity
# 6    18 Del b      18 Del          2            1  Radial Velocity
# 8    24 Boo b      24 Boo          1            1  Radial Velocity
#
#    Discovery Year                 Discovery Facility  Orbital Period Days  \
# 0            2007                   Xinglong Station             326.0300
# 2            2008  Okayama Astrophysical Observatory             185.8400
# 5            2020                   Lick Observatory             578.3800
# 6            2008  Okayama Astrophysical Observatory             993.3000
# 8            2018  Okayama Astrophysical Observatory              30.3506
#
#    Orbit Semi-Major Axis        Mass  Eccentricity Spectral Type  \
# ...

# %% [markdown]
# ## Method Chaining

# %%
import pandas as pd
def load_and_process(url_or_path_to_csv_file):

        df1 = (
              pd.read_csv(url_or_path_to_csv_file)    
              .drop(['No.','Insolation Flux', 'Equilibrium Temperature'], axis=1)
             .rename(columns={'Planet Host': 'Host Star of Planet', 'Orbital Period Days':'Orbital Period in Days'}) 
            .dropna(axis=0)
            )
        
        return df1

# %%
import project_functions3 #Loading the method chain
df = project_functions3.load_and_process("../data/raw/DataOriginal.csv")
df
# Out:
#      Planet Name Host Star of Planet  Num Stars  Num Planets Discovery Method  \
# 0       11 Com b              11 Com          2            1  Radial Velocity
# 2       14 And b              14 And          1            1  Radial Velocity
# 5       17 Sco b              17 Sco          1            1  Radial Velocity
# 6       18 Del b              18 Del          2            1  Radial Velocity
# 8       24 Boo b              24 Boo          1            1  Radial Velocity
# ...          ...                 ...        ...          ...              ...
# 4558   ome Ser b             ome Ser          2            1  Radial Velocity
# 4561    pi Men c            HD 39091          1            2          Transit
# 4563   rho CrB b             rho CrB          1            2  Radial Velocity
# 4564   rho CrB c             rho CrB          1            2  Radial Velocity
# 4570   tau Gem b             tau Gem          1            1  Radial Velocity
#
# ...

# %%
df.describe().T
# Out:
#                                count         mean          std          min  \
# Num Stars                      450.0     1.162222     0.409132     1.000000
# Num Planets                    450.0     1.482222     0.958327     1.000000
# Discovery Year                 450.0  2016.091111     4.214004  1997.000000
# Orbital Period in Days         450.0   465.707277  1354.172653     0.179715
# Orbit Semi-Major Axis          450.0     0.782479     1.538029     0.005800
# Mass                           450.0   737.663258  1284.942434     0.400000
# Eccentricity                   450.0     0.131723     0.179033     0.000000
# Stellar Effective Temperature  450.0  5306.026000   911.884363  3236.000000
# Stellar Radius                 450.0     3.053089     7.263785     0.190000
# Stellar Mass                   450.0     1.086267     0.458087     0.180000
# Stellar Metallicity            450.0     0.032347     0.201607    -1.000000
# ...

# %% [markdown]
# ## Milestone 4

# %% [markdown]
# Exporting data for use in Milestone 4

# %%
import project_functions3
df = project_functions3.load_and_process("../data/raw/DataOriginal.csv")
df.to_csv("../data/processed/DataOriginal.csv")
